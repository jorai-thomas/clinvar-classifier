# %%
import wandb
import numpy as np
import sys
import importlib
import os
from pathlib import Path
from dotenv import load_dotenv

os.environ["WANDB_API_KEY"] = "
sys.path.append(str(Path().resolve().parent))
import config
importlib.reload(config)

# Load API key from .env
load_dotenv()
wandb.login()
print("W&B ready.")
# Out:
# /Users/jorai/Desktop/program/dissertation/clinvar-classifier/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: ERROR Error while calling W&B API: invalid api key (<Response [401]>)
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# W&B ready.

# %%
# ── Run 1: Baseline MLP ───────────────────────────────────────────────────────
run = wandb.init(
    project="clinvar-classifier",
    name="baseline-mlp-allele-only",
    tags=["mlp", "baseline", "allele-only"],
    config={
        "model": "VariantMLP",
        "input_dim": 8,
        "hidden_dims": [64, 32],
        "dropout": 0.3,
        "learning_rate": 1e-3,
        "batch_size": 32,
        "epochs": 50,
        "optimizer": "Adam",
        "loss": "BCEWithLogitsLoss",
        "pos_weight": 4.61,
        "encoding": "allele_onehot",
        "flank": None,
        "dataset": "ClinVar_GRCh38_germline_2star",
        "n_train": 239277,
        "n_val": 34183,
        "n_test": 68365,
        "class_ratio": "4.6:1 Benign:Pathogenic",
        "random_seed": 42,
    }
)

wandb.log({
    "test/auc_overall":       0.5947,
    "test/auc_top50_genes":   0.6554,
    "test/auc_other_genes":   0.5774,
    "test/auc_gap":           0.0780,
    "test/average_precision": 0.227,
})

wandb.run.summary["finding"] = "Allele-only encoding insufficient — AUC 0.59, near random"
wandb.run.summary["equity_gap"] = 0.078
wandb.finish()
print("Run 1 logged.")
# Out:
# wandb: ERROR Error while calling W&B API: invalid api key (<Response [401]>)
# wandb: ERROR Error while calling W&B API: invalid api key (<Response [401]>)
# ---------------------------------------------------------------------------
# CommError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # ── Run 1: Baseline MLP ───────────────────────────────────────────────────────
# ----> 2 run = wandb.init(
#       3     project="clinvar-classifier",
#       4     name="baseline-mlp-allele-only",
#       5     tags=["mlp", "baseline", "allele-only"],
#       6     config={
#       7         "model": "VariantMLP",
#       8         "input_dim": 8,
#       9         "hidden_dims": [64, 32],
#      10         "dropout": 0.3,
#      11         "learning_rate": 1e-3,
#      12         "batch_size": 32,
#      13         "epochs": 50,
#      14         "optimizer": "Adam",
#      15         "loss": "BCEWithLogitsLoss",
# ...
